# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests
import os
import shapefile

# %%
atlantic_url = "https://www.nhc.noaa.gov/data/hurdat/hurdat2-1851-2021-041922.txt"
pacific_url = "https://www.nhc.noaa.gov/data/hurdat/hurdat2-nepac-1949-2021-042522.txt"

# %%
data = {}
url_data ={"atlantic_url": atlantic_url, "pacific_url": pacific_url}
for url in url_data:
    r = requests.get(url_data[url])
    data[url] = r.text.splitlines()

# %%
data["atlantic_url"][:10]

# %%
atlantic_data = {}
event_data = {}
points = []
_id = 1
for line in data["atlantic_url"]:
    values = [v.strip() for v in line.split()]
    if line.strip().endswith(","):
        atlantic_data[_id] = event_data
        points = []
        event_id, event_name, number_of_rows = values
        event_data = {"event_id": event_id, "event_name" : event_name, "number_of_rows": number_of_rows}
        _id += 1
    else:
        day, hour, record_identifier, status, latitude, longitude, max_wind_knots, min_pressure_mb, wind_radii_ne_34, wind_radii_se_34, wind_radii_sw_34, wind_radii_nw_34, wind_radii_ne_50, wind_radii_se_50, wind_radii_sw_50, wind_radii_nw_50, wind_radii_ne_64, wind_radii_se_64, wind_radii_sw_64, wind_radii_nw_64, max_wind_radius = values
        points.append
