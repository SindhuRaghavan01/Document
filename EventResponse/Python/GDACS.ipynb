# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests
import shapefile
import matplotlib.pyplot as mp

# %%
url ="https://www.gdacs.org/gdacsapi/api/polygons/getgeometry?eventtype=FL&eventid=1101298&episodeid=1&polygontype=Global"
url2 = "https://www.gdacs.org/datareport/resources/FL/1101298/geojson_1101298_1.geojson"
url_media_twitter = "https://www.gdacs.org/contentdata/resources/FL/1101298/media_twitter.json"

# %%
r = requests.get(url)

# %%
json_data = r.json()

# %%
json_data.keys()
# Out:
# dict_keys(['type', 'features', 'bbox'])

# %%
json_data["features"]
# Out:
# [{'type': 'Feature',
#   'bbox': [153.26708675123, -28.79363905, 153.26708675123, -28.79363905],
#   'geometry': {'type': 'Point',
#    'coordinates': [153.26708675123, -28.79363905]},
#   'properties': {'eventtype': 'FL',
#    'eventid': 1101298,
#    'episodeid': 1,
#    'eventname': '',
#    'glide': '',
#    'name': 'Flood in Australia',
#    'description': 'Flood in Australia',
#    'htmldescription': 'Green Flood in Australia from: 22 Feb 2022 01 to: 02 Mar 2022 01.',
#    'icon': 'https://www.gdacs.org/images/gdacs_icons/maps/Green/FL.png',
#    'iconoverall': None,
#    'url': {'geometry': 'https://www.gdacs.org/gdacsapi/api/polygons/getgeometry?eventtype=FL&eventid=1101298&episodeid=1',
#     'report': 'https://www.gdacs.org/report.aspx?eventid=1101298&episodeid=1&eventtype=FL',
#     'details': 'https://www.gdacs.org/gdacsapi/api/events/geteventdata?eventtype=FL&eventid=1101298'},
#    'alertlevel': 'Green',
#    'alertscore': 1,
#    'episodealertlevel': 'Green',
# ...

# %%
json_data["features"][1]
# Out:
# {'type': 'Feature',
#  'bbox': [152.679693, -29.0714399, 153.468275, -27.022015],
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[153.254716, -27.350179],
#      [153.256172, -27.349484],
#      [153.259109, -27.3462],
#      [153.25946, -27.345589],
#      [153.260233, -27.345144],
#      [153.261008, -27.343646],
#      [153.261274, -27.342021],
#      [153.26184, -27.340777],
#      [153.26231, -27.339164],
#      [153.2627, -27.338677],
#      [153.262643, -27.337758],
#      [153.262772, -27.337173],
#      [153.263615, -27.335409],
#      [153.26438, -27.334781],
#      [153.264876, -27.333416],
#      [153.264291, -27.332139],
#      [153.26412, -27.332054],
#      [153.262799, -27.332246],
#      [153.262422, -27.332155],
#      [153.26083, -27.33117],
#      [153.259851, -27.330976],
#      [153.259323, -27.330427],
#      [153.259165, -27.329219],
#      [153.258794, -27.328902],
#      [153.256671, -27.328426],
#      [153.255801, -27.328019],
# ...

# %%
import geopandas as gpd

# %%
data = gpd.read_file(url)

# %%
geojson_data = gpd.read_file(url2)
geojson_data.head()
# Out:
#                    id         description                name  \
# 0  FL11012981Centroid  Flood in Australia  Flood in Australia
# 1  FL11012981Affected  Flood in Australia  Flood in Australia
# 2    FL11012981Global  Flood in Australia  Flood in Australia
#
#                                      htmldescription  \
# 0  Green Flood in Australia from: 22 Feb 2022 01:...
# 1  Green Flood in Australia from: 22 Feb 2022 01:...
# 2  Green Flood in Australia from: 22 Feb 2022 01:...
#
#                                                 link featureIndex  \
# 0  https://www.gdacs.org/report.aspx?eventtype=FL...            0
# 1  https://www.gdacs.org/report.aspx?eventtype=FL...            1
# 2  https://www.gdacs.org/report.aspx?eventtype=FL...            2
#
#                                        iconeventlink  \
# 0  https://www.gdacs.org/images/gdacs_icons/maps/...
# 1  https://www.gdacs.org/images/gdacs_icons/maps/...
# 2  https://www.gdacs.org/images/gdacs_icons/maps/...
#
# ...

# %%
geojson_data.geometry[2]

# %%
data.iloc[1].geometry
